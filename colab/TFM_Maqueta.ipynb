# %% [markdown]
# # Maqueta 3D + UTCI — punto de entrada
#
# Tres celdas. Toda la configuración está en `config/zonas/<zona>.json` del repositorio.

# %%
# [1] Drive + repositorio
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import os
REPO = '/content/tfm-maqueta-utci'
URL  = 'https://github.com/benoitcourbin/tfm-maqueta-utci.git'
if os.path.isdir(REPO):
    # !cd {REPO} && git pull --ff-only
else:
    # !git clone {URL} {REPO}
# %cd {REPO}
# Out:
# Mounted at /content/drive
# Cloning into '/content/tfm-maqueta-utci'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 45 (delta 5), reused 45 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (45/45), 43.92 KiB | 956.00 KiB/s, done.
# Resolving deltas: 100% (5/5), done.
# /content/tfm-maqueta-utci

# %%
# [2] Dependencias (triangle no viene en Colab)
# !pip install -q triangle
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 18.7 MB/s eta 0:00:00

# %%
# [3] Ejecución
ZONA = 'lavapies'
# !python run_maqueta.py --zona {ZONA}
# Out:
# Zona lavapies · raíz /content/drive/MyDrive/TFM_UTCI_Lavapies_2026
# ✔ fuente:mdt (0.2 s)
# ✔ fuente:mds (0.2 s)
# ✔ fuente:viario_t03 (1.0 s)
# ✔ fuente:catastro (0.3 s)
# ✔ fuente:arbolado (0.2 s)
# ✗ fuente:epw (0.2 s) — RuntimeError: falta y no se descarga automáticamente
# ✔ fuente:multipatch_01.CENTRO_3D (0.0 s)
# ✔ fuente:multipatch_02.ARGANZUELA_3D (0.0 s)
# Utilidades cargadas.
#
# ==================================================================
#   CAPA : TOPO
# ==================================================================
# ✔ capas:preparar (0.5 s)
#
# ==================================================================
#   CAPA : TOPO
# ==================================================================
# Zona          : lavapies
# BBOX contexto : 439274.77 4472345.06 441079.55 4474148.43  (1805 × 1803 m)
# Paso de malla : 10.0 m  ->  malla prevista 181 × 181 = 32761 vértices
# ✗ https://servpub.madrid.es/georaster/ELEVACIONES/MDT2023_COG/ows        HTTP Error 404: Not Found
# ✔ https://servpub.madrid.es/georaster/ELEVACIONES/MDT2019_COG/ows        0 coberturas
#
# ⚠️ Ningún WCS responde. Se usará el mosaico completo (celda [6], vía alternativa).
# Recorte ya presente : /content/drive/MyDrive/TFM_UTCI_Lavapies_2026/04_VISUALIZACION/Modelo_3D/Data_Contexto/FUENTES/MDT/mdt_lavapies.tif
# Fuente utilizada : caché local
# Ráster origen : 1805 × 1803 px | resolución 1.00 × 1.00 m | CRS EPSG:25830
#   extensión : 439274.77 4472345.43 441079.77 4474148.43
# Malla : 181 × 181 = 32761 vértices | Z 574.23 – 658.95 m
# Desnivel del ámbito : 84.72 m
# Transformación : dx=0.00 dy=0.00 dz=0.00 (Z_MODE=absolute)
# ⚠️ dz debe ser idéntico al de los cuadernos 01 y 02.
# Malla generada : 32761 vértices, 32400 caras
# ✔ topo_lavapies_mesh.json                                  2.09 MB
# ✔ topo_lavapies.obj                                        1.88 MB
# ✔ topo_lavapies_mdt.tif                                    3.47 MB
# ✔ metadata_topo_lavapies.json                              0.00 MB
#
# === CONTROL DE CALIDAD ===
# Extensión respecto al EAP : X -902.4 a +902.3 | Y -901.7 a +901.7
# Z terreno : 574.23 – 658.95 m (desnivel 84.72 m)
#
# Cuaderno 01 : z_mode=absolute dz=0.0
# Base de los edificios : z_min mediana 631.83 m (rango 556.71 – 673.94)
# Terreno               : 574.23 – 658.95 m
#   (los dos rangos deben solaparse ; si el terreno queda muy por debajo,
#    se ha usado un MDS o un sistema vertical distinto)
#
# ✔ Informe : /content/drive/MyDrive/TFM_UTCI_Lavapies_2026/04_VISUALIZACION/Modelo_3D/Data_Contexto/MAQUETA/lavapies/informe_topo_lavapies.md
# Duración total : 11.3 s
# ✔ capa:topo (11.9 s)
#
# ==================================================================
#   CAPA : EDIFICIOS
# ==================================================================
# Zona          : lavapies
# BBOX análisis : 439574.77 4472645.06 440779.55 4473848.43
# BBOX contexto : 439274.77 4472345.06 441079.55 4474148.43  (buffer 300 m)
# EAP           : 440177.20 4473246.72  -> BBox esperada en Rhino : X -902.4 a +902.3 | Y -901.7 a +901.7
# 01.CENTRO_3D           ya presente : ['01_CENTRO.shp']
# 02.ARGANZUELA_3D       ya presente : ['02_ARGANZUELA.shp']
#
# SHP_PATHS (2) : ['01_CENTRO.shp', '02_ARGANZUELA.shp']
# 01_CENTRO.shp                     8292 entidades |  3853 en el ámbito | extensión X 438757–442296 Y 4472978–4480496
# 02_ARGANZUELA.shp                 3799 entidades |  1176 en el ámbito | extensión X 438705–452067 Y 4470603–4478637
# ✔ Ámbito completamente cubierto por los ficheros cargados.
# Total entidades en los ficheros : 12091
# Total retenidas en el ámbito    : 5029
# 01_CENTRO.shp: 100% 3853/3853 [01:34<00:00, 40.58it/s]
# 02_ARGANZUELA.shp: 100% 1176/1176 [00:31<00:00, 37.14it/s]
# Entidades cargadas : 5028
# Duplicados entre distritos descartados : 1
# Anillos interiores (huecos) encontrados : 5662
#   01_CENTRO.shp                  3852
#   02_ARGANZUELA.shp              1176
#   01_EDIFICIO_P                  4217
#   06_ASCENSOR_P                  343
#   01_MARQUESINA_P                224
#   01_PORCHE_CASETA_COBERTIZO_P   189
#   01_QUIOSCO_OBRA_P              52
#   01_DEPOSITO_ELEVADO_P          2
#   01_EDIFICIO_EN_CONSTRUCCIÓN_P  1
# Features de Catastro cargadas : 10228
# Unión espacial: 100% 10228/10228 [00:00<00:00, 28379.11it/s]
# Entidades con al menos 1 correspondencia catastral : 2338 / 5028 (46.5 %)
#   (el GeoJSON sólo cubre Lavapiés : las entidades del buffer quedan sin unir, es normal)
# Parseando GML: 6285621it [00:36, 172928.25it/s]
# Edificios leídos en el GML : 124341 | con año : 124116 | con uso : 124023
# Entidades fechadas : 2338 / 5028 (46.5 %)
# Origen del albedo de fachada : Counter({'defecto': 2690, 'epoca<=1900': 1097, 'epoca<=1940': 507, 'epoca<=1980': 245, 'epoca<=2000': 219, 'epoca<=1960': 155, 'epoca<=9999': 115})
# Años de construcción : mín 1767 / mediana 1905 / máx 2023
# Usos catastrales : [('1_residential', 2146), ('4_3_publicServices', 102), ('4_2_retail', 47), ('4_1_office', 28), ('3_industrial', 13)]
# Transformación : dx=0.00 dy=0.00 dz=0.00 (Z_MODE=absolute)
# ⚠️ dz debe ser idéntico en el cuaderno 02 (viario), si no las dos maquetas quedarán desfasadas.
# mesh.json: 100% 5028/5028 [00:16<00:00, 296.00it/s]
# OBJ: 100% 5028/5028 [00:22<00:00, 227.68it/s]
# ✔ edificios_lavapies_mesh.json                           163.32 MB
# ✔ edificios_lavapies.obj                                 165.35 MB
# ✔ edificios_lavapies_3d.geojson                          147.39 MB
# ✔ edificios_lavapies_atributos.csv                         1.01 MB
# ✔ edificios_lavapies_huellas.geojson                      25.35 MB
# ✔ metadata_edificios_lavapies.json                         0.00 MB
#
# === CONTROL DE CALIDAD ===
# Extensión real de la geometría : X 439244.3–452067.2 | Y 4471614.5–4478637.5
#   respecto al EAP            : X -932.9 a +11890.0 | Y -1632.3 a +5390.8
#   esperado (bbox contexto)   : X -902.4 a +902.3 | Y -901.7 a +901.7
#   (un déficit por un lado = distrito colindante ausente ; un exceso = entidades
#    a caballo del borde, conservadas enteras : es normal)
# Alturas : mín 0.2 / mediana 27.1 / máx 88.1 m
# Z absoluta : 556.7 – 710.3 m
# Caras totales : 788769
# Alturas sospechosas (<2 m o >80 m) : 208
# Sin huella 2D calculable : 0
# Sin año de construcción : 2690
# Desviación altura Madrid - Catastro : mediana +9.94 m sobre 2338 entidades
#   (desviación positiva = Catastro infravalora ; esperable, la cubierta real supera el alero)
#
# ✔ Informe : /content/drive/MyDrive/TFM_UTCI_Lavapies_2026/04_VISUALIZACION/Modelo_3D/Data_Contexto/MAQUETA/lavapies/informe_edificios_lavapies.md
# Duración total : 297.9 s
# ✔ capa:edificios (298.1 s)
#
# ==================================================================
#   CAPA : VIARIO
# ==================================================================
# Tema 03 ya presente en /content/drive/MyDrive/TFM_UTCI_Lavapies_2026/04_VISUALIZACION/Modelo_3D/Data_Contexto/FUENTES/Madrid_Viario/Viario_T03
# Capas disponibles : 40
# 03_ACERA_P             acera          309 polígonos |   463970 m²
# 03_ACERA_NIVEL_P       acera          180 polígonos |   120092 m²
# 03_VADO_P              vado           522 polígonos |    11550 m²
# 03_ISLETA_P            isleta          72 polígonos |    36005 m²
# 03_ADOQUINADO_L        adoquinado      75 polígonos |     1514 m²  (poligonizados desde 409 líneas)
#
# Superficies cartografiadas : 1158 polígonos, 633131 m²
# Huellas de edificios : 5028 (1662001 m²)
# Espacio público (bbox − edificado) : 1653069 m²
# Calzada bruta                      : 1154185 m²
# Calzada retenida : 798 polígonos, 1015018 m²
# Descartado como patio interior : 3921 polígonos, 138437 m²
# Adoquinado aplicado como prioridad : 1956 polígonos tras el recorte
#
#                                n     area_m2  ancho_medio
# clase      material
# calzada    asfalto           798  1015017.53         2.00
# acera      hormigon_baldosa  489   582918.85         2.87
# isleta     hormigon           72    36004.55         2.84
# vado       hormigon          522    11549.97         1.85
# adoquinado adoquin_granito    75     1514.02         0.81
#
# Anchura de calzada : mediana 2.00 m | P10 0.38 | P90 9.10
#   (tejido histórico : valores de 4–10 m son coherentes)
# MDT cargado : topo_lavapies_mdt.tif (1805 × 1803 px)
# Transformación : dx=0.00 dy=0.00 dz=0.00 offset_z=0.020 (Z_MODE=absolute)
# Triangulando: 100% 1956/1956 [00:20<00:00, 97.10it/s]
# Objetos triangulados : 1956 | caras 90946  (simplify 0.10 m, densificar 10.0 m)
#    superficie : 1647005 -> 1646932 m2  (-0.0044 %)  <- debe ser despreciable
# ✔ viario_lavapies_mesh.json                                5.11 MB
# ✔ viario_lavapies.obj                                      4.85 MB
# ✔ viario_lavapies.geojson                                 13.29 MB
# ✔ viario_lavapies_atributos.csv                            0.13 MB
# ✔ metadata_viario_lavapies.json                            0.00 MB
#
# === CONTROL DE CALIDAD ===
# Superficie de viario : 1647005 m² sobre 3254686 m² de ámbito (50.6 %)
# Superficie edificada : 1661230 m² (51.0 %)
# Suma viario + edificado : 101.6 % del ámbito
#   (debe acercarse al 100 %% ; el déficit son patios interiores y zonas verdes)
# Solape entre clases : 1.34 %
#   (debe ser ~0 : el adoquinado ya recorta las capas inferiores)
# Z del viario : 574.59 – 671.59 m
# Base de los edificios : z_min mediana 631.83 m
#   (viario y base de edificios deben estar en el mismo rango)
#
# ✔ Informe : /content/drive/MyDrive/TFM_UTCI_Lavapies_2026/04_VISUALIZACION/Modelo_3D/Data_Contexto/MAQUETA/lavapies/informe_viario_lavapies.md
# Duración total : 67.2 s
# ✔ capa:viario (68.0 s)
#
# ==================================================================
#   CAPA : ARBOLADO
# ==================================================================
# Inventario : 3927 registros | columnas : ['CODIGO_ESPECIE', 'nombre_especie', 'forma_copa', 'diametro_tronco_cm', 'altura_total_m', 'h_inicio_follaje_m', 'X', 'Y', 'longitud', 'latitud', 'NBRE_BARRIO']
# Árboles dentro del ámbito : 3927
# Descartados por altura fuera de rango (1,5–45 m) : 9
#
# Altura total   : mín 1.5 | mediana 7.5 | máx 20.0 m
# Inicio follaje : mediana 3.2 m
# Tronco         : mediana 15.9 cm
#
# Especies más frecuentes :
#   Aligustre del Japón           663
#   Plátano de sombra             477
#   Acacia del Japón              366
#   Falsa acacia                  245
#   Almez                         234
#   Arce negundo                  198
#   Olmo de Siberia               158
#   Pino piñonero                 134
#   Pino marítimo                 116
#   Jabonero de China             110
# Formas de copa : {'Esférica': np.int64(1241), 'Extendida': np.int64(1194), 'Ovoide': np.int64(683), 'Cónica': np.int64(333), 'Irregular': np.int64(318), 'Parasol': np.int64(134), 'Columnar': np.int64(15)}
# MDT : 1805 × 1803 px | resolución 1.00 m
# Cota de base : 587.60 – 653.76 m
# nDSM (MDS − MDT) : 1805 × 1803 px | altura 0 – 60.0 m | media 12.78 m
# Máscara del edificado : 5028 huellas, buffer 1.0 m
#    píxeles enmascarados : 1939159 (59.6 % del ámbito)
#    CHM > 0 : 2914195 → 1008830 px | altura media 12.78 → 4.02 m
#    (la media debe caer del orden de la altura del edificado a la de los árboles)
# h_copa (altura − inicio de follaje) : p10 2.0 | mediana 4.2 | p90 8.4 m
# Píxeles de vegetación (CHM >= 2.0 m) : 385117 (11.8 % del ámbito)
# Semillas : 3747 colocadas | 713 fuera de vegetación (547 recuperadas a < 3.0 m)
#    5 árboles comparten píxel con otro : se miden por alometría
# Segmentación : watershed (skimage) sobre −CHM
# Copas segmentadas : 3008 | descartadas por inverosímiles : 910
#
# Calibración de R = D / h_copa sobre los árboles medidos
#   forma            n  R med.   desv. R usado   origen
#   Columnar        12       —       —    0.35   declarado (n < 20)
#   Cónica         253    0.94    0.52    0.94   calibrado
#   Esférica       938    1.19    0.55    1.19   calibrado
#   Extendida      951    1.03    0.55    1.03   calibrado
#   Irregular      246    1.08    0.53    1.08   calibrado
#   Ovoide         539    1.06    0.53    1.06   calibrado
#   Parasol         69    1.51    0.70    1.51   calibrado
# Método utilizado : {'chm': 3008, 'alometria': 910}
# Diámetro de copa : mín 1.5 | mediana 4.4 | máx 24.0 m
#   mediana CHM 4.79 m vs alometría 3.25 m (desviación +1.54 m)
#   (R ya está calibrado sobre el CHM : una desviación grande señala
#    una segmentación aún contaminada, no un problema de coeficientes)
# Origen del LAI : {'tabla': 1375, 'defecto': 2543}
# Transmisividad verano   : mediana 0.174
# Transmisividad invierno : mediana 0.819
#   (T = exp(−0.5 × LAI) ; T bajo = follaje opaco)
# ⚠️ 72 especies sin LAI en tabla (se usa el genérico) : ['Abedul pubescente', 'Abedul verrucoso', 'Abeto de Douglas', 'Acacia de tres espinas', 'Acacia del Japón', 'Acacia rosa', 'Ailanto', 'Aligustre común', 'Aligustre del Japón', 'Aliso común', 'Amelanchier', 'Araucaria']
# Huellas de edificios : 5028
# Colisiones: 100% 3918/3918 [00:01<00:00, 2184.88it/s]
#
# Árboles dentro de una huella de edificio : 0 (0.0 %)
# Copas que penetraban el edificado        : 753 (19.2 %)
#   reducción de diámetro : mediana 2.06 m | máx 13.26 m
#   (si la mediana supera 1–2 m, la alometría sobrestima : priorizar el CHM,
#    que mide la copa real y por tanto ya restringida por el edificado)
# Transformación : dx=0.00 dy=0.00 dz=0.00 (Z_MODE=absolute)
# Geometría: 100% 3918/3918 [00:01<00:00, 3675.56it/s]
# Objetos generados : 7836 (3918 árboles)
# Vértices : 143073 | caras : 140532
# ✔ arbolado_lavapies_mesh.json                             11.71 MB
# ✔ arbolado_lavapies_atributos.csv                          0.66 MB
# ✔ arbolado_lavapies_puntos.geojson                         2.17 MB
# ✔ arbolado_lavapies.obj                                    8.06 MB
# ✔ metadata_arbolado_lavapies.json                          0.00 MB
#
# === CONTROL DE CALIDAD ===
# Árboles : 3918 | copa por CHM : 3008 | por alometría : 910
# Colisiones : {'ok': 3165, 'colision': 753}
# Relación diámetro/altura : mediana 0.60 (P10 0.32 – P90 0.99)
#   (valores plausibles ~0,3–1,0 ; fuera de ahí revisar el método)
# Proyección de copas : 104432 m² = 3.2 % del ámbito
#   (Lavapiés es un tejido denso con poco arbolado : un 3–10 %% es coherente)
# Z del arbolado : 587.60 – 670.63 m
# Base de los edificios : z_min mediana 631.83 m
#
# ✔ Informe : /content/drive/MyDrive/TFM_UTCI_Lavapies_2026/04_VISUALIZACION/Modelo_3D/Data_Contexto/MAQUETA/lavapies/informe_arbolado_lavapies.md
# Duración total : 25.9 s
# ✔ capa:arbolado (25.9 s)
#
# ==================================================================
#   CAPA : LOD1
# ==================================================================
# Zona    : lavapies
# OUT_DIR : /content/drive/MyDrive/TFM_UTCI_Lavapies_2026/04_VISUALIZACION/Modelo_3D/Data_Contexto/MAQUETA/lavapies
# ✗ capa:lod1 (0.0 s) — ModuleNotFoundError: No module named 'ijson'
# MDT : 1805 x 1803 px | corregidos 1192 px (|dz| > 5.0 m, ventana 21 m) | sin dato 0
# Huellas : 4842 polígonos -> 1602203 m2
#   adoquinado       1484 m2
#   acera          483555 m2
#   isleta          13357 m2
#   vado              329 m2
#   calzada       1014668 m2
#   relleno        139090 m2
# Caras polygonizadas : 26195
# Simplificación de cobertura 0.25 : 304714 -> 244502 vértices de borde
# Caras de suelo : 19746 | {'acera': 3274, 'calzada': 3627, 'relleno': 12586, 'isleta': 170, 'adoquinado': 80, 'vado': 9}
#
# === CONTROL DE CALIDAD ===
# Caras no trianguladas : 0 | repli Delaunay shapely : 0 | triángulos perdidos : 0
# Aristas de borde : 52471 en límite (marco / fachada) | 74 desnudas
#   (desnudas debe ser 0 : superficie continua entre clases)
# Bordillos por par de clases (m) : {('acera', 'calzada'): 154474, ('calzada', 'relleno'): 10278, ('calzada', 'isleta'): 5682, ('acera', 'adoquinado'): 1565, ('acera', 'vado'): 98, ('relleno', 'vado'): 20, ('adoquinado', 'relleno'): 11}
# Bordillos : 172128 m lineales en 357 objetos
# Suelo : 1652463 m2 | edificado 1602203 m2 | suma 100.00 % del marco
# Objetos por clase : {'acera': 354, 'adoquinado': 9, 'calzada': 359, 'isleta': 58, 'relleno': 351, 'vado': 6, 'bordillo': 357}
# Caras por clase   : {'acera': 40641, 'adoquinado': 806, 'calzada': 44878, 'isleta': 1340, 'relleno': 29186, 'vado': 30, 'bordillo': 56366}
# Caras totales : 173247 (todas triangulares)
# Z : 573.03 – 659.24 m
# Suelo − MDT bruto (píxel) : p1 -0.11 | mediana 0.00 | p99 0.10 | |dz|>1 m : 109 / 87815
# ✔ suelo_lavapies_mesh.json  10.86 MB
# ✔ mdt_limpio_lavapies.tif
# Duración : 234.3 s
# ✔ suelo (234.6 s)
# ✔ manifiesto (0.9 s)
#
# Informe : /content/drive/MyDrive/TFM_UTCI_Lavapies_2026/04_VISUALIZACION/Modelo_3D/DOCS/INFORMES/informe_ejecucion_lavapies.md
# Pasos con fallo : 2

# %%
# !python run_maqueta.py --zona chamberi --pasos fuentes
# Out:
# Traceback (most recent call last):
#   File "/content/tfm-maqueta-utci/run_maqueta.py", line 138, in <module>
#     sys.exit(main())
#              ~~~~^^
#   File "/content/tfm-maqueta-utci/run_maqueta.py", line 39, in main
#     cfg, rutas = cargar_zona(args.zona)
#                  ~~~~~~~~~~~^^^^^^^^^^^
#   File "/content/tfm-maqueta-utci/src/tfm/rutas.py", line 117, in cargar_zona
#     raise RuntimeError('No existe %s. Copia lavapies.json y edítalo.' % ruta)
# RuntimeError: No existe /content/tfm-maqueta-utci/config/zonas/chamberi.json. Copia lavapies.json y edítalo.

# %% [markdown]
# El informe queda en `DOCS/INFORMES/informe_ejecucion_<zona>.md` y el manifiesto en `MAQUETA/<zona>/manifest_<zona>.json`.
#
# Después de la simulación en Rhino:
#
# ```
# !python exportar_resultados.py --zona lavapies --sim '/content/drive/MyDrive/.../simulation_v5' --version v5
# ```
